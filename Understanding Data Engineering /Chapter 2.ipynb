# %% [markdown]
# # Chapter 2 *Data Structures*

# %% [markdown]
# ##Structured Data

# %% [markdown]
# This type of **Data** is entered following a rigid structure, like a spreadsheeet where there are set columns:
#
# * It's easy to search and organize
#
# * It has a consistent model, rows and columns.
#
# * It has defined types
#
# * It's stored in relational databases
#
# * About 20% of the data is structured
#
# * It's created and queried using SQL (*Structured Query Language*)

# %% [markdown]
# ###Example

# %% [markdown]
# Employee Table
#
# |  | | | | | | |
# |--|--|--|--|--|--|--|
# |index|last_name|first_name|role|team|full_time|office|
# |0|Thien|Vivian|Data Engineer| Data Science|1|Belgium|
# |1|Huong|Julian|Data Scientist| Data Science | 1 | Belgium|
# |2|Duplantier|Norbert|Software Developer| Sales| 1| United Kingdom|

# %% [markdown]
# ## Semi-structured Data

# %% [markdown]
# * It's Relatively easy to search and organize
#
# * It allows a less-rigid implementation : different observations have different sizes
#
# * It allows different types
#
# * Can be grouped, but needs more work
#
# * NoSQL databases: JSON, XML , YAML

# %% [markdown]
# ### Example

# %% [markdown]
# Air BNB JSON file

# %%
[
  {
    "name": "Cozy Downtown Loft",
    "review_scores": {
      "rating": 4.8
    },
    "price": 100
  },
  {
    "name": "Modern Studio Near Park",
    "review_scores": {
      "rating": 4.9
    },
    "price": 85
  },
  {
    "name": "Historic Home with Garden",
    "review_scores": {
      "rating": 4.6
    },
    "price": 120
  },
  {
    "name": "Basic Room in Shared Apartment",
    "review_scores": {
      "rating": 4.2
    },
    "price": 45
  }
]

# %% [markdown]
# ##Unstructured Data

# %% [markdown]
# *  Does not follow a model, can't be contained in row and columns
#
# * Difficult to search and organize
#
# * Usually text, sound , pictures or videos
#
# * Usually stored in data lakes, can appear in data warehouses or databases
#
# * Most data is unstructured
#
# * Can be extremely valuable

# %% [markdown]
# ###How to add structure?

# %% [markdown]
# * Use AI to search and organize unstructured data
#
# * Add information to make it semi-structured

# %% [markdown]
# ##SQL
# * Structured query Language
#
# * Industry standard for Relational Database Management System (RDBMS)
#
# * Allows you to access many records at once, and group, filter or aggregate them.
#
#
# * Close to written English, easy to write and understand
#
# * Used by **Data engineers** to create and maintain databases

# %% [markdown]
# ###SQL for data Engineers

# %% [markdown]
# * Data engineers use SQL to create, maintain and update tables

# %%
CREATE TABLE employees (
    employee_id INT,
    first_name VARCHAR(255),
    last_name VARCHAR(255),
    email VARCHAR(255),
    hire_date DATE,
    department_id INT,
    full_time BOOLEAN,
    office VARCHAR(255)
);

# %% [markdown]
# ###SQL for data scientists

# %% [markdown]
# * Data scientist use SQL to query, fitler, group and aggregate data in tables

# %%
SELECT first_name, last_name
FROM employees
WHERE role LIKE '%Data%'

# %% [markdown]
# ###Database Schema

# %% [markdown]
# * Databases are made of tables
#
# * The database schema governs how tables are related ![Screenshot 2025-05-13 at 8.25.24 PM.png](data:image/png;base64,...)

# %% [markdown]
# ##Data Lakes an data Warehouses
# |||
# |--|--|
# |Data lake| Data Warehouse|
# |Stores all the raw data| Specific data for specific use|
# |Can be petabytes( 1 million GBs)|Relatively small|
# |Stores all data structures| Store mainly structured data|
# |Cost-effective | More costly to update|
# |Difficult to analyze| Optimized for data analysis|
# |Requires an up-to-date data catalog||
# |Used by data scientists||
# Big data, real time analytics||

# %% [markdown]
# ### A data catalog must exist within a data lake

# %% [markdown]
# * What is the source of this data?
#
# * Where is this data used?
#
# * Who is the owner of the data?
#
# * How often is this data updated?
#
# * Good practice in terms of data governance
#
# * Ensures reproducibility
#
# * No catalog -> Risk of turning into a data swamp
